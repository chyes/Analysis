# %%
import numpy as np
import pandas as pd
import re
import wordcloud
import collections

# %%
df = pd.read_csv(r'C:\Users\Administrator\Desktop\doubanSpider\movie\rawMovies.csv')
df
# Out:
#        Unnamed: 0  actor_count  \
# 0               0            4
# 1               1            1
# 2               2            4
# 3               3            0
# 4               4            7
# 5               5            5
# 6               6            4
# 7               7            0
# 8               8            4
# 9               9            0
# 10             10            0
# 11             11            3
# 12             12            1
# 13             13            0
# 14             14           15
# 15             15            1
# 16             16            3
# 17             17            0
# 18             18            3
# 19             19            1
# 20             20            1
# 21             21           11
# 22             22            1
# 23             23            1
# 24             24            0
# 25             25            1
# 26             26            4
# 27             27            0
# 28             28           10
# ...

# %%
df = df.drop(df.columns[0], axis=1)
df
# Out:
#        actor_count                                             actors  \
# 0                4                      ['久石让', '大桥望美', '高畑勋', '宫崎骏']
# 1                1                                         ['大卫·爱登堡']
# 2                4           ['保罗·麦卡特尼', '乔治·哈里逊', '林哥·斯塔尔', '约翰·列侬']
# 3                0                                                 []
# 4                7  ['达蒙·奥尔本', '戴夫·罗恩特里', '菲尔·丹尼尔斯', '利亚姆·加拉格尔', '...
# 5                5              ['大野智', '樱井翔', '相叶雅纪', '二宫和也', '松本润']
# 6                4          ['玛吉·史密斯', '丹尼尔·雷德克里夫', '约翰·赫特', '艾玛·沃森']
# 7                0                                                 []
# 8                4        ['丹尼尔·雷德克里夫', '艾玛·沃森', '鲁伯特·格林特', '马修·刘易斯']
# 9                0                                                 []
# 10               0                                                 []
# 11               3                              ['高以翔', '曲婉婷', '夏克立']
# ...

# %%
df.describe()
# Out:
#         actor_count            id          rank         score    vote_count
# count  47282.000000  4.728200e+04  47282.000000  47282.000000  4.728200e+04
# mean      14.583711  8.760577e+06   1440.869633      6.951358  2.982354e+04
# std       11.680078  1.052089e+07   1364.644808      1.213587  8.789307e+04
# min        0.000000  1.291543e+06      1.000000      2.000000  3.010000e+02
# 25%        7.000000  1.307770e+06    427.000000      6.300000  1.426000e+03
# 50%       12.000000  2.346824e+06   1004.000000      7.100000  4.033000e+03
# 75%       19.000000  2.027880e+07   2007.000000      7.800000  1.649300e+04
# max      100.000000  3.495376e+07   6394.000000      9.700000  1.777843e+06

# %%
df.describe(include=['O'])
# Out:
#        actors                                          cover_url  \
# count   47282                                              47282
# unique  20597                                              22190
# top        []  https://img1.doubanio.com/view/photo/s_ratio_p...
# freq     1677                                                 10
#
#                rating regions release_date  title         types  \
# count           47282   47282        47282  47282         47282
# unique             86    1675         9168  21249          2851
# top     ['7.5', '40']  ['美国']         2010     保镖  ['剧情', '爱情']
# freq             1945   13939          153     17          1378
#
#                                               url
# count                                       47282
# unique                                      22192
# top     https://movie.douban.com/subject/1306513/
# freq                                           10

# %%
df.info
# Out:
# <bound method DataFrame.info of        actor_count                                             actors  \
# 0                4                      ['久石让', '大桥望美', '高畑勋', '宫崎骏']
# 1                1                                         ['大卫·爱登堡']
# 2                4           ['保罗·麦卡特尼', '乔治·哈里逊', '林哥·斯塔尔', '约翰·列侬']
# 3                0                                                 []
# 4                7  ['达蒙·奥尔本', '戴夫·罗恩特里', '菲尔·丹尼尔斯', '利亚姆·加拉格尔', '...
# 5                5              ['大野智', '樱井翔', '相叶雅纪', '二宫和也', '松本润']
# 6                4          ['玛吉·史密斯', '丹尼尔·雷德克里夫', '约翰·赫特', '艾玛·沃森']
# 7                0                                                 []
# 8                4        ['丹尼尔·雷德克里夫', '艾玛·沃森', '鲁伯特·格林特', '马修·刘易斯']
# 9                0                                                 []
# 10               0                                                 []
# 11               3                              ['高以翔', '曲婉婷', '夏克立']
# ...

# %%
# 去重
df = df.drop_duplicates()
df
# Out:
#        actor_count                                             actors  \
# 0                4                      ['久石让', '大桥望美', '高畑勋', '宫崎骏']
# 1                1                                         ['大卫·爱登堡']
# 2                4           ['保罗·麦卡特尼', '乔治·哈里逊', '林哥·斯塔尔', '约翰·列侬']
# 3                0                                                 []
# 4                7  ['达蒙·奥尔本', '戴夫·罗恩特里', '菲尔·丹尼尔斯', '利亚姆·加拉格尔', '...
# 5                5              ['大野智', '樱井翔', '相叶雅纪', '二宫和也', '松本润']
# 6                4          ['玛吉·史密斯', '丹尼尔·雷德克里夫', '约翰·赫特', '艾玛·沃森']
# 7                0                                                 []
# 8                4        ['丹尼尔·雷德克里夫', '艾玛·沃森', '鲁伯特·格林特', '马修·刘易斯']
# 9                0                                                 []
# 10               0                                                 []
# 11               3                              ['高以翔', '曲婉婷', '夏克立']
# ...

# %%
df = df[df.actor_count !=0]
df.to_csv(r'C:\Users\Administrator\Desktop\doubanSpider\movie\1.csv', encoding='utf8', index=None)

# %%
from PIL import Image # 图像处理库
import matplotlib.pyplot as plt # 图像展示库
ll = []
for i in df.actors:
    i = re.split(r"\[|'|\]|\,", i)
    for j in i:
        if j and j != ' ':
            ll.append(j)
print(ll[:200])
# 词频统计
word_counts = collections.Counter(ll) # 对分词做词频统计
print(word_counts) # 输出检查
# 词频展示
mask = np.array(Image.open(r'C:\Users\Administrator\Desktop\1.jpg')) # 定义词频背景
wc = wordcloud.WordCloud(
    font_path='C:/Windows/Fonts/simhei.ttf', # 设置字体格式
    mask=mask, # 设置背景图
    max_words=100, # 最多显示词数
    max_font_size=100, # 字体最大值
    height= 609,
    width=440
)
wc.generate_from_frequencies(word_counts) # 从字典生成词云
image_colors = wordcloud.ImageColorGenerator(mask) # 从背景图建立颜色方案
wc.recolor(color_func=image_colors) # 将词云颜色设置为背景图方案
plt.imshow(wc) # 显示词云
plt.axis('off') # 关闭坐标轴
plt.show() # 显示图像
